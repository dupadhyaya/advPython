# %% [markdown]
# # PySpark - Introduction
# - !pip install pyspark

# %%
#pip install pyspark

# %%
from pyspark.sql import SparkSession  # add this import
import os
import pandas as pd

# %%
spark = SparkSession.builder.master("local[*]").appName("local").getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://195.168.2.70:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.1.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Datacamp Pyspark Tutorial</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
path = "/Users/du/dup/analytics/projects/advPython/data/datacamp_ecommerce.csv"

# %%
print(os.environ.get("JAVA_HOME"))
# Out:
# None

# %%
df1 = pd.read_csv(path)
df1.head()
# Out:
#    Index  InvoiceNo StockCode                         Description  Quantity  \
# 0      0     536571     84991         60 TEATIME FAIRY CAKE CASES         1
# 1      1     536122     84625       PINK CHERRY LIGHTS STRING SET        10
# 2      2     536122     22197                      POPCORN HOLDER         5
# 3      3     539108     84969  BOX OF 6 ASSORTED COLOUR TEASPOONS         3
# 4      4     539108     22616           PACK OF 12 LONDON TISSUES         2
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/24/10 11:43       0.55       14006  United Kingdom
# 1   12/3/10 14:14       4.65       15456  United Kingdom
# 2   12/3/10 14:14       1.65       17865  United Kingdom
# 3  12/26/10 13:44       4.25       19121  United Kingdom
# 4  12/26/10 13:44       1.45       19841  United Kingdom

# %%
df = (spark.read.option("header", True).option("inferSchema", True).csv(path))
# Out:
# 25/12/26 12:28:14 WARN FileStreamSink: Assume no metadata directory. Error while looking for metadata directory in the path: /Users/du/dup/analytics/projects/advPython/data/datacamp_ecommerce.csv.
# java.lang.UnsupportedOperationException: getSubject is supported only if a security manager is allowed
# 	at java.base/javax.security.auth.Subject.getSubject(Subject.java:347)
# 	at org.apache.hadoop.security.UserGroupInformation.getCurrentUser(UserGroupInformation.java:588)
# 	at org.apache.hadoop.fs.FileSystem$Cache$Key.<init>(FileSystem.java:3888)
# 	at org.apache.hadoop.fs.FileSystem$Cache$Key.<init>(FileSystem.java:3878)
# 	at org.apache.hadoop.fs.FileSystem$Cache.get(FileSystem.java:3666)
# 	at org.apache.hadoop.fs.FileSystem.get(FileSystem.java:557)
# 	at org.apache.hadoop.fs.FileSystem.get(FileSystem.java:289)
# 	at org.apache.hadoop.fs.FileSystem.get(FileSystem.java:541)
# 	at org.apache.hadoop.fs.Path.getFileSystem(Path.java:366)
# ...

# %%
os.listdir('./data/')
# Out:
# ['datacamp_ecommerce.csv']

# %%
df = spark.read.csv("/Users/du/dup/analytics/projects/advPython/data/datacamp_ecommerce.csv")
# Out:
# 25/12/26 12:25:09 WARN FileStreamSink: Assume no metadata directory. Error while looking for metadata directory in the path: /Users/du/dup/analytics/projects/advPython/data/datacamp_ecommerce.csv.
# java.lang.UnsupportedOperationException: getSubject is supported only if a security manager is allowed
# 	at java.base/javax.security.auth.Subject.getSubject(Subject.java:347)
# 	at org.apache.hadoop.security.UserGroupInformation.getCurrentUser(UserGroupInformation.java:588)
# 	at org.apache.hadoop.fs.FileSystem$Cache$Key.<init>(FileSystem.java:3888)
# 	at org.apache.hadoop.fs.FileSystem$Cache$Key.<init>(FileSystem.java:3878)
# 	at org.apache.hadoop.fs.FileSystem$Cache.get(FileSystem.java:3666)
# 	at org.apache.hadoop.fs.FileSystem.get(FileSystem.java:557)
# 	at org.apache.hadoop.fs.FileSystem.get(FileSystem.java:289)
# 	at org.apache.hadoop.fs.FileSystem.get(FileSystem.java:541)
# 	at org.apache.hadoop.fs.Path.getFileSystem(Path.java:366)
# ...

# %%
df = spark.read \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .csv("/Users/du/dup/analytics/projects/advPython/data/datacamp_ecommerce.csv")
# Out:
# 25/12/26 12:22:08 WARN FileStreamSink: Assume no metadata directory. Error while looking for metadata directory in the path: /Users/du/dup/analytics/projects/advPython/data/datacamp_ecommerce.csv.
# java.lang.UnsupportedOperationException: getSubject is supported only if a security manager is allowed
# 	at java.base/javax.security.auth.Subject.getSubject(Subject.java:347)
# 	at org.apache.hadoop.security.UserGroupInformation.getCurrentUser(UserGroupInformation.java:588)
# 	at org.apache.hadoop.fs.FileSystem$Cache$Key.<init>(FileSystem.java:3888)
# 	at org.apache.hadoop.fs.FileSystem$Cache$Key.<init>(FileSystem.java:3878)
# 	at org.apache.hadoop.fs.FileSystem$Cache.get(FileSystem.java:3666)
# 	at org.apache.hadoop.fs.FileSystem.get(FileSystem.java:557)
# 	at org.apache.hadoop.fs.FileSystem.get(FileSystem.java:289)
# 	at org.apache.hadoop.fs.FileSystem.get(FileSystem.java:541)
# 	at org.apache.hadoop.fs.Path.getFileSystem(Path.java:366)
# ...

# %%
df = spark.read.csv("./data/datacamp_ecommerce.csv", header=True, escape='"', inferSchema=True)
# Out:
# 25/12/26 12:20:05 WARN FileStreamSink: Assume no metadata directory. Error while looking for metadata directory in the path: ./data/datacamp_ecommerce.csv.
# java.lang.UnsupportedOperationException: getSubject is supported only if a security manager is allowed
# 	at java.base/javax.security.auth.Subject.getSubject(Subject.java:347)
# 	at org.apache.hadoop.security.UserGroupInformation.getCurrentUser(UserGroupInformation.java:588)
# 	at org.apache.hadoop.fs.FileSystem$Cache$Key.<init>(FileSystem.java:3888)
# 	at org.apache.hadoop.fs.FileSystem$Cache$Key.<init>(FileSystem.java:3878)
# 	at org.apache.hadoop.fs.FileSystem$Cache.get(FileSystem.java:3666)
# 	at org.apache.hadoop.fs.FileSystem.get(FileSystem.java:557)
# 	at org.apache.hadoop.fs.FileSystem.get(FileSystem.java:289)
# 	at org.apache.hadoop.fs.FileSystem.get(FileSystem.java:541)
# 	at org.apache.hadoop.fs.Path.getFileSystem(Path.java:366)
# ...
